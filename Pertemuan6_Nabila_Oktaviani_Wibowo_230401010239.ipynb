# %% [markdown]
# # PERTEMUAN 6 - Persiapan Data
#
# **Nama Lengkap**: Nabila Oktaviani Wibowo
#
# **NIM**: 230401010239
#
# **Kelas**: IF405

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

df = pd.DataFrame({
    'Gender':['male','female','female','male']
})

le = LabelEncoder()

df['Gender_enc'] = le.fit_transform(df['Gender'])

df
# Out:
#    Gender  Gender_enc
# 0    male           1
# 1  female           0
# 2  female           0
# 3    male           1

# %%
pd.get_dummies(
    pd.DataFrame({
        'City':['Jakarta','Bandung','Surabaya']
    })
)
# Out:
#    City_Bandung  City_Jakarta  City_Surabaya
# 0         False          True          False
# 1          True         False          False
# 2         False         False           True

# %%
from sklearn.preprocessing import OrdinalEncoder

df = pd.DataFrame({
    'Pendidikan':['SMA','S1','S2']
})

enc = OrdinalEncoder(
    categories=[['SMA','S1','S2']]
)

df['Pendidikan_enc'] = enc.fit_transform(
    df[['Pendidikan']]
)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit_transform(
    [[25,5],
     [45,20],
     [32,8]]
)
# Out:
# array([[0.  , 0.  ],
#        [1.  , 1.  ],
#        [0.35, 0.2 ]])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit_transform(
    [[25,5],
     [45,20],
     [32,8]]
)
# Out:
# array([[-1.08609928, -0.9258201 ],
#        [ 1.32745468,  1.38873015],
#        [-0.2413554 , -0.46291005]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

iris = load_iris()

X_train, X_test, y_train, y_test = train_test_split(
    iris.data,
    iris.target,
    test_size=0.2,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (120, 4)
# (30, 4)

# %% [markdown]
# ## Kesimpulan
#
# Praktikum ini membahas tahapan preprocessing data sebelum Machine Learning.
#
# Temuan utama:
# - Data kategorikal perlu diubah menjadi numerik.
# - Scaling membantu menyamakan skala fitur.
# - Train-test split penting untuk evaluasi model yang valid.
#
# Keterbatasan:
# - Belum menggunakan pipeline preprocessing secara lengkap pada dataset besar.
