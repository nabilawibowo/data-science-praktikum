# %% [markdown]
# # =======================
# PERTEMUAN 1 : Notebook Pertama Data Science
#
# **Nama Lengkap** : Nabila Oktaviani Wibowo
#
# **NIM** : 230401010239
#
# **Kelas** : IF405
#
# # =======================

# %% [markdown]
# **SEL 1 : OUTPUT SEDERHANA**

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# **SEL 2 : Variabel dan tipe data dasar**

# %%
# SEL 2: Variabel dan tipe data dasar

nama = "Mahasiswa Informatika"   # String
angkatan = 2023                  # Integer
ipk = 3.75                       # Float
aktif = True                     # Boolean

print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk}")
print(f"Aktif     : {aktif}")
# Out:
# Nama      : Mahasiswa Informatika
# Angkatan  : 2023
# IPK       : 3.75
# Aktif     : True

# %% [markdown]
# **SEL 3 : List & Looping**

# %%
# SEL 3: List dan perulangan

tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %% [markdown]
# **SEL 4 : Function**

# %%
# SEL 4: Fungsi sederhana

def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Nabila Oktaviani Wibowo", "Informatika", 2023)
print(hasil)
# Out:
# Hai saya Nabila Oktaviani Wibowo dari Informatika, angkatan 2023.

# %% [markdown]
# ## Kesimpulan
#
# Pada pertemuan ini saya mempelajari:
# - Cara menampilkan output di Python
# - Penggunaan variabel dan tipe data (string, integer, float, boolean)
# - Penggunaan list dan perulangan (loop)
# - Cara membuat fungsi sederhana
#
# Temuan:
# - Python sangat mudah dibaca dan digunakan untuk pemula
# - Looping mempermudah pengolahan data berulang
#
# Keterbatasan / Pertanyaan:
# - Belum mencoba dataset nyata
# - Ingin memahami penggunaan Python untuk analisis data lebih lanjut
